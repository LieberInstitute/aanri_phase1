# %% [markdown]
# # GO analysis using GOATOOLS

# %%
import functools
import errno, os
import pandas as pd
import collections as cx
from pybiomart import Dataset
# GO analysis
from goatools.base import download_go_basic_obo
from goatools.base import download_ncbi_associations
from goatools.obo_parser import GODag
from goatools.anno.genetogo_reader import Gene2GoReader
from goatools.goea.go_enrichment_ns import GOEnrichmentStudyNS

# %%
os.environ['NUMEXPR_MAX_THREADS'] = '10'

# %%
@functools.lru_cache()
def get_database():
    dataset = Dataset(name="hsapiens_gene_ensembl", 
                      host="http://www.ensembl.org",
                      use_cache=True)
    db = dataset.query(attributes=["ensembl_gene_id", 
                                   "external_gene_name", 
                                   "entrezgene_id"], 
                       use_attr_names=True).dropna(subset=['entrezgene_id'])
    return db


@functools.lru_cache()
def get_deg_with_modality():
    fn = '../../_m/degs_with_modality.txt'
    return pd.read_csv(fn, sep='\t', index_col=0)


@functools.lru_cache()
def get_uni_modality():
    df = get_deg_with_modality()
    return df[(df['Modality_AA'] == 1) & (df['Modality_EA'] == 1)]


@functools.lru_cache()
def get_AAonly_modality():
    df = get_deg_with_modality()
    return df[(df['Modality_AA'] >= 2) & (df['Modality_EA'] == 1)]


@functools.lru_cache()
def get_EAonly_modality():
    df = get_deg_with_modality()
    return df[(df['Modality_AA'] == 1) & (df['Modality_EA'] >= 2)]


@functools.lru_cache()
def get_multi_modality():
    df = get_deg_with_modality()
    return df[(df['Modality_AA'] > 1) & (df['Modality_EA'] > 1)]


@functools.lru_cache()
def convert2entrez(deg_func):
    df = deg_func()
    if 'EntrezID' in df.columns:
        return df.rename(columns={'EntrezID': 'entrezgene_id'})
    else: 
        return df.merge(get_database(), left_on='ensemblID', 
                        right_on='ensembl_gene_id')
    

@functools.lru_cache()
def get_upregulated(deg_func):
    df = convert2entrez(deg_func)
    return df.loc[(df['t'] > 0)]
    
    
@functools.lru_cache()
def get_downregulated(deg_func):
    df = convert2entrez(deg_func)
    return df.loc[(df['t'] < 0)]

# %%
def mkdir_p(directory):
    try:
        os.makedirs(directory)
    except OSError as e:
        if e.errno != errno.EEXIST:
            raise
            

def obo_annotation(alpha=0.05):
    # database annotation
    fn_obo = download_go_basic_obo()
    fn_gene2go = download_ncbi_associations() # must be gunzip to work
    obodag = GODag(fn_obo) # downloads most up-to-date
    anno_hs = Gene2GoReader(fn_gene2go, taxids=[9606])
    # get associations
    ns2assoc = anno_hs.get_ns2assc()
    for nspc, id2gos in ns2assoc.items():
        print("{NS} {N:,} annotated human genes".format(NS=nspc, N=len(id2gos)))
    goeaobj = GOEnrichmentStudyNS(
        get_database()['entrezgene_id'], # List of human genes with entrez IDs
        ns2assoc, # geneid/GO associations
        obodag, # Ontologies
        propagate_counts = False,
        alpha = alpha, # default significance cut-off
        methods = ['fdr_bh'])
    return goeaobj


def run_goea(deg_func, outdir):
    df = convert2entrez(deg_func)
    geneids_study = {z[0]:z[1] for z in zip(df['entrezgene_id'], df['Symbol'])}
    goeaobj = obo_annotation()
    goea_results_all = goeaobj.run_study(geneids_study)
    goea_results_sig = [r for r in goea_results_all if r.p_fdr_bh < 0.05]
    ctr = cx.Counter([r.NS for r in goea_results_sig])
    print('Significant results[{TOTAL}] = {BP} BP + {MF} MF + {CC} CC'.format(
        TOTAL=len(goea_results_sig),
        BP=ctr['BP'],  # biological_process
        MF=ctr['MF'],  # molecular_function
        CC=ctr['CC'])) # cellular_component
    label = "all"
    goeaobj.wr_xlsx("%s/GO_analysis_%s.xlsx" % (outdir, label), goea_results_sig)
    goeaobj.wr_txt("%s/GO_analysis_%s.txt" % (outdir, label), goea_results_sig)
    
    
def run_goea_direction(direction, deg_func, outdir):
    df = get_upregulated(deg_func) if direction == 'Up' else get_downregulated(deg_func)
    geneids_study = {z[0]:z[1] for z in zip(df['entrezgene_id'], df['Symbol'])}
    goeaobj = obo_annotation()
    goea_results_all = goeaobj.run_study(geneids_study)
    goea_results_sig = [r for r in goea_results_all if r.p_fdr_bh < 0.05]
    ctr = cx.Counter([r.NS for r in goea_results_sig])
    print('Significant results[{TOTAL}] = {BP} BP + {MF} MF + {CC} CC'.format(
        TOTAL=len(goea_results_sig),
        BP=ctr['BP'],  # biological_process
        MF=ctr['MF'],  # molecular_function
        CC=ctr['CC'])) # cellular_component
    label = "upregulated" if direction == "Up" else "downregulated"
    goeaobj.wr_xlsx("%s/GO_analysis_%s.xlsx" % (outdir, label), goea_results_sig)
    goeaobj.wr_txt("%s/GO_analysis_%s.txt" % (outdir, label), goea_results_sig)

# %% [markdown]
# ## Multimodal AA only

# %% [markdown]
# ### All DEG

# %%
directory = 'AAonly'
mkdir_p(directory)
run_goea(get_AAonly_modality, directory)
# Out:
#   EXISTS: go-basic.obo
#   EXISTS: gene2go
# go-basic.obo: fmt(1.2) rel(2020-09-10) 47,314 GO Terms
# HMS:0:00:05.077761 340,574 annotations, 20,692 genes, 18,417 GOs, 1 taxids READ: gene2go
# MF 18,165 annotated human genes
# CC 19,419 annotated human genes
# BP 18,665 annotated human genes
#
# Load BP Gene Ontology Analysis ...
#  70% 20,474 of 29,114 population items found in association
#
# Load CC Gene Ontology Analysis ...
#  73% 21,385 of 29,114 population items found in association
#
# Load MF Gene Ontology Analysis ...
#  70% 20,291 of 29,114 population items found in association
#
# Run BP Gene Ontology Analysis: current study set of 854 IDs ... 80%    509 of    633 study items found in association
#  74%    633 of    854 study items found in population(29114)
# Calculating 12,344 uncorrected p-values using fisher
#   12,344 GO terms are associated with 18,029 of 29,114 population items
#    2,391 GO terms are associated with    509 of    854 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 854 IDs ... 85%    536 of    633 study items found in association
#  74%    633 of    854 study items found in population(29114)
# Calculating 1,758 uncorrected p-values using fisher
#    1,758 GO terms are associated with 18,719 of 29,114 population items
#      464 GO terms are associated with    536 of    854 study items
#   METHOD fdr_bh:
#        9 GO terms found significant (< 0.05=alpha) (  9 enriched +   0 purified): statsmodels fdr_bh
#      335 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 854 IDs ... 82%    522 of    633 study items found in association
#  74%    633 of    854 study items found in population(29114)
# Calculating 4,243 uncorrected p-values using fisher
#    4,243 GO terms are associated with 17,826 of 29,114 population items
#      723 GO terms are associated with    522 of    854 study items
#   METHOD fdr_bh:
#        1 GO terms found significant (< 0.05=alpha) (  1 enriched +   0 purified): statsmodels fdr_bh
#      372 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# Significant results[10] = 0 BP + 1 MF + 9 CC
#      10 items WROTE: AAonly/GO_analysis_all.xlsx
#      10 GOEA results for   462 study items. WROTE: AAonly/GO_analysis_all.txt

# %% [markdown]
# ### Upregulated DEG

# %%
direction = "Up"
run_goea_direction(direction, get_AAonly_modality, directory)
# Out:
#   EXISTS: go-basic.obo
#   EXISTS: gene2go
# go-basic.obo: fmt(1.2) rel(2020-09-10) 47,314 GO Terms
# HMS:0:00:05.314919 340,574 annotations, 20,692 genes, 18,417 GOs, 1 taxids READ: gene2go
# MF 18,165 annotated human genes
# CC 19,419 annotated human genes
# BP 18,665 annotated human genes
#
# Load BP Gene Ontology Analysis ...
#  70% 20,474 of 29,114 population items found in association
#
# Load CC Gene Ontology Analysis ...
#  73% 21,385 of 29,114 population items found in association
#
# Load MF Gene Ontology Analysis ...
#  70% 20,291 of 29,114 population items found in association
#
# Run BP Gene Ontology Analysis: current study set of 483 IDs ... 78%    262 of    337 study items found in association
#  70%    337 of    483 study items found in population(29114)
# Calculating 12,344 uncorrected p-values using fisher
#   12,344 GO terms are associated with 18,029 of 29,114 population items
#    1,425 GO terms are associated with    262 of    483 study items
#   METHOD fdr_bh:
#        1 GO terms found significant (< 0.05=alpha) (  1 enriched +   0 purified): statsmodels fdr_bh
#       30 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 483 IDs ... 84%    282 of    337 study items found in association
#  70%    337 of    483 study items found in population(29114)
# Calculating 1,758 uncorrected p-values using fisher
#    1,758 GO terms are associated with 18,719 of 29,114 population items
#      300 GO terms are associated with    282 of    483 study items
#   METHOD fdr_bh:
#        4 GO terms found significant (< 0.05=alpha) (  4 enriched +   0 purified): statsmodels fdr_bh
#       90 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 483 IDs ... 80%    270 of    337 study items found in association
#  70%    337 of    483 study items found in population(29114)
# Calculating 4,243 uncorrected p-values using fisher
#    4,243 GO terms are associated with 17,826 of 29,114 population items
#      441 GO terms are associated with    270 of    483 study items
#   METHOD fdr_bh:
#        1 GO terms found significant (< 0.05=alpha) (  1 enriched +   0 purified): statsmodels fdr_bh
#      186 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# Significant results[6] = 1 BP + 1 MF + 4 CC
#       6 items WROTE: AAonly/GO_analysis_upregulated.xlsx
#       6 GOEA results for   219 study items. WROTE: AAonly/GO_analysis_upregulated.txt

# %% [markdown]
# ### Downregulated DEG

# %%
direction = "Down"
run_goea_direction(direction, get_AAonly_modality, directory)
# Out:
#   EXISTS: go-basic.obo
#   EXISTS: gene2go
# go-basic.obo: fmt(1.2) rel(2020-09-10) 47,314 GO Terms
# HMS:0:00:05.219546 340,574 annotations, 20,692 genes, 18,417 GOs, 1 taxids READ: gene2go
# MF 18,165 annotated human genes
# CC 19,419 annotated human genes
# BP 18,665 annotated human genes
#
# Load BP Gene Ontology Analysis ...
#  70% 20,474 of 29,114 population items found in association
#
# Load CC Gene Ontology Analysis ...
#  73% 21,385 of 29,114 population items found in association
#
# Load MF Gene Ontology Analysis ...
#  70% 20,291 of 29,114 population items found in association
#
# Run BP Gene Ontology Analysis: current study set of 371 IDs ... 83%    247 of    296 study items found in association
#  80%    296 of    371 study items found in population(29114)
# Calculating 12,344 uncorrected p-values using fisher
#   12,344 GO terms are associated with 18,029 of 29,114 population items
#    1,464 GO terms are associated with    247 of    371 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 371 IDs ... 86%    254 of    296 study items found in association
#  80%    296 of    371 study items found in population(29114)
# Calculating 1,758 uncorrected p-values using fisher
#    1,758 GO terms are associated with 18,719 of 29,114 population items
#      338 GO terms are associated with    254 of    371 study items
#   METHOD fdr_bh:
#        7 GO terms found significant (< 0.05=alpha) (  7 enriched +   0 purified): statsmodels fdr_bh
#      182 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 371 IDs ... 85%    252 of    296 study items found in association
#  80%    296 of    371 study items found in population(29114)
# Calculating 4,243 uncorrected p-values using fisher
#    4,243 GO terms are associated with 17,826 of 29,114 population items
#      444 GO terms are associated with    252 of    371 study items
#   METHOD fdr_bh:
#        1 GO terms found significant (< 0.05=alpha) (  1 enriched +   0 purified): statsmodels fdr_bh
#      186 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# Significant results[8] = 0 BP + 1 MF + 7 CC
#       8 items WROTE: AAonly/GO_analysis_downregulated.xlsx
#       8 GOEA results for   224 study items. WROTE: AAonly/GO_analysis_downregulated.txt

# %% [markdown]
# ## Multimodal EA only

# %% [markdown]
# ### All DEG

# %%
directory = 'EAonly'
mkdir_p(directory)
run_goea(get_EAonly_modality, directory)
# Out:
#   EXISTS: go-basic.obo
#   EXISTS: gene2go
# go-basic.obo: fmt(1.2) rel(2020-09-10) 47,314 GO Terms
# HMS:0:00:05.198410 340,574 annotations, 20,692 genes, 18,417 GOs, 1 taxids READ: gene2go
# MF 18,165 annotated human genes
# CC 19,419 annotated human genes
# BP 18,665 annotated human genes
#
# Load BP Gene Ontology Analysis ...
#  70% 20,474 of 29,114 population items found in association
#
# Load CC Gene Ontology Analysis ...
#  73% 21,385 of 29,114 population items found in association
#
# Load MF Gene Ontology Analysis ...
#  70% 20,291 of 29,114 population items found in association
#
# Run BP Gene Ontology Analysis: current study set of 557 IDs ... 79%    314 of    399 study items found in association
#  72%    399 of    557 study items found in population(29114)
# Calculating 12,344 uncorrected p-values using fisher
#   12,344 GO terms are associated with 18,029 of 29,114 population items
#    1,635 GO terms are associated with    314 of    557 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 557 IDs ... 83%    331 of    399 study items found in association
#  72%    399 of    557 study items found in population(29114)
# Calculating 1,758 uncorrected p-values using fisher
#    1,758 GO terms are associated with 18,719 of 29,114 population items
#      376 GO terms are associated with    331 of    557 study items
#   METHOD fdr_bh:
#        1 GO terms found significant (< 0.05=alpha) (  1 enriched +   0 purified): statsmodels fdr_bh
#       11 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 557 IDs ... 78%    312 of    399 study items found in association
#  72%    399 of    557 study items found in population(29114)
# Calculating 4,243 uncorrected p-values using fisher
#    4,243 GO terms are associated with 17,826 of 29,114 population items
#      523 GO terms are associated with    312 of    557 study items
#   METHOD fdr_bh:
#        1 GO terms found significant (< 0.05=alpha) (  1 enriched +   0 purified): statsmodels fdr_bh
#      229 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# Significant results[2] = 0 BP + 1 MF + 1 CC
#       2 items WROTE: EAonly/GO_analysis_all.xlsx
#       2 GOEA results for   232 study items. WROTE: EAonly/GO_analysis_all.txt

# %% [markdown]
# ### Upregulated DEG

# %%
direction = "Up"
run_goea_direction(direction, get_EAonly_modality, directory)
# Out:
#   EXISTS: go-basic.obo
#   EXISTS: gene2go
# go-basic.obo: fmt(1.2) rel(2020-09-10) 47,314 GO Terms
# HMS:0:00:05.807447 340,574 annotations, 20,692 genes, 18,417 GOs, 1 taxids READ: gene2go
# MF 18,165 annotated human genes
# CC 19,419 annotated human genes
# BP 18,665 annotated human genes
#
# Load BP Gene Ontology Analysis ...
#  70% 20,474 of 29,114 population items found in association
#
# Load CC Gene Ontology Analysis ...
#  73% 21,385 of 29,114 population items found in association
#
# Load MF Gene Ontology Analysis ...
#  70% 20,291 of 29,114 population items found in association
#
# Run BP Gene Ontology Analysis: current study set of 307 IDs ... 80%    162 of    202 study items found in association
#  66%    202 of    307 study items found in population(29114)
# Calculating 12,344 uncorrected p-values using fisher
#   12,344 GO terms are associated with 18,029 of 29,114 population items
#      945 GO terms are associated with    162 of    307 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 307 IDs ... 84%    169 of    202 study items found in association
#  66%    202 of    307 study items found in population(29114)
# Calculating 1,758 uncorrected p-values using fisher
#    1,758 GO terms are associated with 18,719 of 29,114 population items
#      261 GO terms are associated with    169 of    307 study items
#   METHOD fdr_bh:
#        1 GO terms found significant (< 0.05=alpha) (  1 enriched +   0 purified): statsmodels fdr_bh
#        8 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 307 IDs ... 79%    160 of    202 study items found in association
#  66%    202 of    307 study items found in population(29114)
# Calculating 4,243 uncorrected p-values using fisher
#    4,243 GO terms are associated with 17,826 of 29,114 population items
#      305 GO terms are associated with    160 of    307 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# Significant results[1] = 0 BP + 0 MF + 1 CC
#       1 items WROTE: EAonly/GO_analysis_upregulated.xlsx
#       1 GOEA results for     8 study items. WROTE: EAonly/GO_analysis_upregulated.txt

# %% [markdown]
# ### Downregulated DEG

# %%
direction = "Down"
run_goea_direction(direction, get_EAonly_modality, directory)
# Out:
#   EXISTS: go-basic.obo
#   EXISTS: gene2go
# go-basic.obo: fmt(1.2) rel(2020-09-10) 47,314 GO Terms
# HMS:0:00:05.276081 340,574 annotations, 20,692 genes, 18,417 GOs, 1 taxids READ: gene2go
# MF 18,165 annotated human genes
# CC 19,419 annotated human genes
# BP 18,665 annotated human genes
#
# Load BP Gene Ontology Analysis ...
#  70% 20,474 of 29,114 population items found in association
#
# Load CC Gene Ontology Analysis ...
#  73% 21,385 of 29,114 population items found in association
#
# Load MF Gene Ontology Analysis ...
#  70% 20,291 of 29,114 population items found in association
#
# Run BP Gene Ontology Analysis: current study set of 250 IDs ... 77%    152 of    197 study items found in association
#  79%    197 of    250 study items found in population(29114)
# Calculating 12,344 uncorrected p-values using fisher
#   12,344 GO terms are associated with 18,029 of 29,114 population items
#      954 GO terms are associated with    152 of    250 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 250 IDs ... 82%    162 of    197 study items found in association
#  79%    197 of    250 study items found in population(29114)
# Calculating 1,758 uncorrected p-values using fisher
#    1,758 GO terms are associated with 18,719 of 29,114 population items
#      222 GO terms are associated with    162 of    250 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 250 IDs ... 77%    152 of    197 study items found in association
#  79%    197 of    250 study items found in population(29114)
# Calculating 4,243 uncorrected p-values using fisher
#    4,243 GO terms are associated with 17,826 of 29,114 population items
#      328 GO terms are associated with    152 of    250 study items
#   METHOD fdr_bh:
#        1 GO terms found significant (< 0.05=alpha) (  1 enriched +   0 purified): statsmodels fdr_bh
#      119 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# Significant results[1] = 0 BP + 1 MF + 0 CC
#       1 items WROTE: EAonly/GO_analysis_downregulated.xlsx
#       1 GOEA results for   119 study items. WROTE: EAonly/GO_analysis_downregulated.txt

# %% [markdown]
# ## Multimodal both ethnicity

# %% [markdown]
# ### All DEG

# %%
directory = 'both_multimodal'
mkdir_p(directory)
run_goea(get_multi_modality, directory)
# Out:
#   EXISTS: go-basic.obo
#   EXISTS: gene2go
# go-basic.obo: fmt(1.2) rel(2020-09-10) 47,314 GO Terms
# HMS:0:00:05.512838 340,574 annotations, 20,692 genes, 18,417 GOs, 1 taxids READ: gene2go
# MF 18,165 annotated human genes
# CC 19,419 annotated human genes
# BP 18,665 annotated human genes
#
# Load BP Gene Ontology Analysis ...
#  70% 20,474 of 29,114 population items found in association
#
# Load CC Gene Ontology Analysis ...
#  73% 21,385 of 29,114 population items found in association
#
# Load MF Gene Ontology Analysis ...
#  70% 20,291 of 29,114 population items found in association
#
# Run BP Gene Ontology Analysis: current study set of 586 IDs ... 79%    278 of    352 study items found in association
#  60%    352 of    586 study items found in population(29114)
# Calculating 12,344 uncorrected p-values using fisher
#   12,344 GO terms are associated with 18,029 of 29,114 population items
#    1,587 GO terms are associated with    278 of    586 study items
#   METHOD fdr_bh:
#        6 GO terms found significant (< 0.05=alpha) (  6 enriched +   0 purified): statsmodels fdr_bh
#       17 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 586 IDs ... 82%    289 of    352 study items found in association
#  60%    352 of    586 study items found in population(29114)
# Calculating 1,758 uncorrected p-values using fisher
#    1,758 GO terms are associated with 18,719 of 29,114 population items
#      333 GO terms are associated with    289 of    586 study items
#   METHOD fdr_bh:
#        9 GO terms found significant (< 0.05=alpha) (  9 enriched +   0 purified): statsmodels fdr_bh
#      156 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 586 IDs ... 77%    270 of    352 study items found in association
#  60%    352 of    586 study items found in population(29114)
# Calculating 4,243 uncorrected p-values using fisher
#    4,243 GO terms are associated with 17,826 of 29,114 population items
#      468 GO terms are associated with    270 of    586 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# Significant results[15] = 6 BP + 0 MF + 9 CC
#      15 items WROTE: both_multimodal/GO_analysis_all.xlsx
#      15 GOEA results for   162 study items. WROTE: both_multimodal/GO_analysis_all.txt

# %% [markdown]
# ### Upregulated DEG

# %%
direction = "Up"
run_goea_direction(direction, get_multi_modality, directory)
# Out:
#   EXISTS: go-basic.obo
#   EXISTS: gene2go
# go-basic.obo: fmt(1.2) rel(2020-09-10) 47,314 GO Terms
# HMS:0:00:05.454834 340,574 annotations, 20,692 genes, 18,417 GOs, 1 taxids READ: gene2go
# MF 18,165 annotated human genes
# CC 19,419 annotated human genes
# BP 18,665 annotated human genes
#
# Load BP Gene Ontology Analysis ...
#  70% 20,474 of 29,114 population items found in association
#
# Load CC Gene Ontology Analysis ...
#  73% 21,385 of 29,114 population items found in association
#
# Load MF Gene Ontology Analysis ...
#  70% 20,291 of 29,114 population items found in association
#
# Run BP Gene Ontology Analysis: current study set of 339 IDs ... 74%    148 of    199 study items found in association
#  59%    199 of    339 study items found in population(29114)
# Calculating 12,344 uncorrected p-values using fisher
#   12,344 GO terms are associated with 18,029 of 29,114 population items
#      875 GO terms are associated with    148 of    339 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 339 IDs ... 79%    158 of    199 study items found in association
#  59%    199 of    339 study items found in population(29114)
# Calculating 1,758 uncorrected p-values using fisher
#    1,758 GO terms are associated with 18,719 of 29,114 population items
#      227 GO terms are associated with    158 of    339 study items
#   METHOD fdr_bh:
#        8 GO terms found significant (< 0.05=alpha) (  8 enriched +   0 purified): statsmodels fdr_bh
#       85 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 339 IDs ... 72%    143 of    199 study items found in association
#  59%    199 of    339 study items found in population(29114)
# Calculating 4,243 uncorrected p-values using fisher
#    4,243 GO terms are associated with 17,826 of 29,114 population items
#      262 GO terms are associated with    143 of    339 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# Significant results[8] = 0 BP + 0 MF + 8 CC
#       8 items WROTE: both_multimodal/GO_analysis_upregulated.xlsx
#       8 GOEA results for    85 study items. WROTE: both_multimodal/GO_analysis_upregulated.txt

# %% [markdown]
# ### Downregulated DEG

# %%
direction = "Down"
run_goea_direction(direction, get_multi_modality, directory)
# Out:
#   EXISTS: go-basic.obo
#   EXISTS: gene2go
# go-basic.obo: fmt(1.2) rel(2020-09-10) 47,314 GO Terms
# HMS:0:00:05.182071 340,574 annotations, 20,692 genes, 18,417 GOs, 1 taxids READ: gene2go
# MF 18,165 annotated human genes
# CC 19,419 annotated human genes
# BP 18,665 annotated human genes
#
# Load BP Gene Ontology Analysis ...
#  70% 20,474 of 29,114 population items found in association
#
# Load CC Gene Ontology Analysis ...
#  73% 21,385 of 29,114 population items found in association
#
# Load MF Gene Ontology Analysis ...
#  70% 20,291 of 29,114 population items found in association
#
# Run BP Gene Ontology Analysis: current study set of 247 IDs ... 85%    130 of    153 study items found in association
#  62%    153 of    247 study items found in population(29114)
# Calculating 12,344 uncorrected p-values using fisher
#   12,344 GO terms are associated with 18,029 of 29,114 population items
#      950 GO terms are associated with    130 of    247 study items
#   METHOD fdr_bh:
#        6 GO terms found significant (< 0.05=alpha) (  6 enriched +   0 purified): statsmodels fdr_bh
#       16 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 247 IDs ... 86%    131 of    153 study items found in association
#  62%    153 of    247 study items found in population(29114)
# Calculating 1,758 uncorrected p-values using fisher
#    1,758 GO terms are associated with 18,719 of 29,114 population items
#      201 GO terms are associated with    131 of    247 study items
#   METHOD fdr_bh:
#        3 GO terms found significant (< 0.05=alpha) (  3 enriched +   0 purified): statsmodels fdr_bh
#       86 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 247 IDs ... 83%    127 of    153 study items found in association
#  62%    153 of    247 study items found in population(29114)
# Calculating 4,243 uncorrected p-values using fisher
#    4,243 GO terms are associated with 17,826 of 29,114 population items
#      283 GO terms are associated with    127 of    247 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# Significant results[9] = 6 BP + 0 MF + 3 CC
#       9 items WROTE: both_multimodal/GO_analysis_downregulated.xlsx
#       9 GOEA results for    88 study items. WROTE: both_multimodal/GO_analysis_downregulated.txt

# %% [markdown]
# ## Unimodal both ethnicity

# %% [markdown]
# ### All DEG

# %%
directory = 'unimodal'
mkdir_p(directory)
run_goea(get_uni_modality, directory)
# Out:
#   EXISTS: go-basic.obo
#   EXISTS: gene2go
# go-basic.obo: fmt(1.2) rel(2020-09-10) 47,314 GO Terms
# HMS:0:00:05.512838 340,574 annotations, 20,692 genes, 18,417 GOs, 1 taxids READ: gene2go
# MF 18,165 annotated human genes
# CC 19,419 annotated human genes
# BP 18,665 annotated human genes
#
# Load BP Gene Ontology Analysis ...
#  70% 20,474 of 29,114 population items found in association
#
# Load CC Gene Ontology Analysis ...
#  73% 21,385 of 29,114 population items found in association
#
# Load MF Gene Ontology Analysis ...
#  70% 20,291 of 29,114 population items found in association
#
# Run BP Gene Ontology Analysis: current study set of 586 IDs ... 79%    278 of    352 study items found in association
#  60%    352 of    586 study items found in population(29114)
# Calculating 12,344 uncorrected p-values using fisher
#   12,344 GO terms are associated with 18,029 of 29,114 population items
#    1,587 GO terms are associated with    278 of    586 study items
#   METHOD fdr_bh:
#        6 GO terms found significant (< 0.05=alpha) (  6 enriched +   0 purified): statsmodels fdr_bh
#       17 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 586 IDs ... 82%    289 of    352 study items found in association
#  60%    352 of    586 study items found in population(29114)
# Calculating 1,758 uncorrected p-values using fisher
#    1,758 GO terms are associated with 18,719 of 29,114 population items
#      333 GO terms are associated with    289 of    586 study items
#   METHOD fdr_bh:
#        9 GO terms found significant (< 0.05=alpha) (  9 enriched +   0 purified): statsmodels fdr_bh
#      156 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 586 IDs ... 77%    270 of    352 study items found in association
#  60%    352 of    586 study items found in population(29114)
# Calculating 4,243 uncorrected p-values using fisher
#    4,243 GO terms are associated with 17,826 of 29,114 population items
#      468 GO terms are associated with    270 of    586 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# Significant results[15] = 6 BP + 0 MF + 9 CC
#      15 items WROTE: both_multimodal/GO_analysis_all.xlsx
#      15 GOEA results for   162 study items. WROTE: both_multimodal/GO_analysis_all.txt

# %% [markdown]
# ### Upregulated DEG

# %%
direction = "Up"
run_goea_direction(direction, get_uni_modality, directory)
# Out:
#   EXISTS: go-basic.obo
#   EXISTS: gene2go
# go-basic.obo: fmt(1.2) rel(2020-09-10) 47,314 GO Terms
# HMS:0:00:05.454834 340,574 annotations, 20,692 genes, 18,417 GOs, 1 taxids READ: gene2go
# MF 18,165 annotated human genes
# CC 19,419 annotated human genes
# BP 18,665 annotated human genes
#
# Load BP Gene Ontology Analysis ...
#  70% 20,474 of 29,114 population items found in association
#
# Load CC Gene Ontology Analysis ...
#  73% 21,385 of 29,114 population items found in association
#
# Load MF Gene Ontology Analysis ...
#  70% 20,291 of 29,114 population items found in association
#
# Run BP Gene Ontology Analysis: current study set of 339 IDs ... 74%    148 of    199 study items found in association
#  59%    199 of    339 study items found in population(29114)
# Calculating 12,344 uncorrected p-values using fisher
#   12,344 GO terms are associated with 18,029 of 29,114 population items
#      875 GO terms are associated with    148 of    339 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 339 IDs ... 79%    158 of    199 study items found in association
#  59%    199 of    339 study items found in population(29114)
# Calculating 1,758 uncorrected p-values using fisher
#    1,758 GO terms are associated with 18,719 of 29,114 population items
#      227 GO terms are associated with    158 of    339 study items
#   METHOD fdr_bh:
#        8 GO terms found significant (< 0.05=alpha) (  8 enriched +   0 purified): statsmodels fdr_bh
#       85 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 339 IDs ... 72%    143 of    199 study items found in association
#  59%    199 of    339 study items found in population(29114)
# Calculating 4,243 uncorrected p-values using fisher
#    4,243 GO terms are associated with 17,826 of 29,114 population items
#      262 GO terms are associated with    143 of    339 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# Significant results[8] = 0 BP + 0 MF + 8 CC
#       8 items WROTE: both_multimodal/GO_analysis_upregulated.xlsx
#       8 GOEA results for    85 study items. WROTE: both_multimodal/GO_analysis_upregulated.txt

# %% [markdown]
# ### Downregulated DEG

# %%
direction = "Down"
run_goea_direction(direction, get_uni_modality, directory)
# Out:
#   EXISTS: go-basic.obo
#   EXISTS: gene2go
# go-basic.obo: fmt(1.2) rel(2020-09-10) 47,314 GO Terms
# HMS:0:00:05.182071 340,574 annotations, 20,692 genes, 18,417 GOs, 1 taxids READ: gene2go
# MF 18,165 annotated human genes
# CC 19,419 annotated human genes
# BP 18,665 annotated human genes
#
# Load BP Gene Ontology Analysis ...
#  70% 20,474 of 29,114 population items found in association
#
# Load CC Gene Ontology Analysis ...
#  73% 21,385 of 29,114 population items found in association
#
# Load MF Gene Ontology Analysis ...
#  70% 20,291 of 29,114 population items found in association
#
# Run BP Gene Ontology Analysis: current study set of 247 IDs ... 85%    130 of    153 study items found in association
#  62%    153 of    247 study items found in population(29114)
# Calculating 12,344 uncorrected p-values using fisher
#   12,344 GO terms are associated with 18,029 of 29,114 population items
#      950 GO terms are associated with    130 of    247 study items
#   METHOD fdr_bh:
#        6 GO terms found significant (< 0.05=alpha) (  6 enriched +   0 purified): statsmodels fdr_bh
#       16 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 247 IDs ... 86%    131 of    153 study items found in association
#  62%    153 of    247 study items found in population(29114)
# Calculating 1,758 uncorrected p-values using fisher
#    1,758 GO terms are associated with 18,719 of 29,114 population items
#      201 GO terms are associated with    131 of    247 study items
#   METHOD fdr_bh:
#        3 GO terms found significant (< 0.05=alpha) (  3 enriched +   0 purified): statsmodels fdr_bh
#       86 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 247 IDs ... 83%    127 of    153 study items found in association
#  62%    153 of    247 study items found in population(29114)
# Calculating 4,243 uncorrected p-values using fisher
#    4,243 GO terms are associated with 17,826 of 29,114 population items
#      283 GO terms are associated with    127 of    247 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# Significant results[9] = 6 BP + 0 MF + 3 CC
#       9 items WROTE: both_multimodal/GO_analysis_downregulated.xlsx
#       9 GOEA results for    88 study items. WROTE: both_multimodal/GO_analysis_downregulated.txt
