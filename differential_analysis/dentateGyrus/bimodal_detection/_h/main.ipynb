# %% [markdown]
# # Detect bimodal distribution for DEGs by ethnicity

# %%
import functools
import numpy as np
import pandas as pd
from sklearn import mixture

# %%
config = {
    'deg_file': '../../_m/genes/diffExpr_EAvsAA_full.txt',
    'res_file': '../../_m/genes/residualized_expression.tsv',
    'pheno_file': '../../../../../input/phenotypes/_m/dg_phenotypes.csv',
}

# %%
@functools.lru_cache()
def get_deg():
    ''' Take significant DE genes obtained from limma-voom pipeline.
    '''
    return pd.read_csv(config['deg_file'], sep='\t', index_col=0)


@functools.lru_cache()
def get_deg_sig(fdr=0.05):
    ''' Take significant DE genes obtained from limma-voom pipeline.
    '''
    dft = get_deg()
    return dft[(dft['adj.P.Val'] < fdr)]


@functools.lru_cache()
def get_residualized():
    '''Load residualization file.
    '''
    return pd.read_csv(config['res_file'], sep='\t', index_col=0).transpose()


@functools.lru_cache()
def get_deg_res_df():
    res_df = get_residualized()
    return res_df[np.array(get_deg().index)]


@functools.lru_cache()
def get_pheno_data():
    return pd.read_csv(config['pheno_file'], index_col=0)


@functools.lru_cache()
def get_pheno_res_df():
    return get_pheno_data().merge(get_deg_res_df(), left_index=True, right_index=True)

# %%
def gaussian_mixture_test(X, num=7):
    lowest_bic = np.infty
    bic = []
    n_components_range = range(1, num)
    for n_components in n_components_range:
        # Fit a Gaussian mixture with EM
        gmm = mixture.GaussianMixture(n_components=n_components, 
                                      covariance_type='spherical')
        gmm.fit(X)
        bic.append(gmm.bic(X))
        if bic[-1] < lowest_bic:
            best_n = n_components
            lowest_bic = bic[-1]
    return best_n

# %%
df = get_pheno_res_df()
aa = df[(df['Race'] == 'AA')].copy()
ea = df[(df['Race'] == 'CAUC')].copy()
modality_aa = []; modality_ea = [];

for gene in np.array(get_deg_sig().gencodeID):
    Xaa = np.array(aa[gene]).reshape(-1, 1)
    Xea = np.array(ea[gene]).reshape(-1, 1)
    modality_aa.append(gaussian_mixture_test(Xaa))
    modality_ea.append(gaussian_mixture_test(Xea))

# %%
dt = get_deg_sig()
dt.loc[:,'Modality_AA'] = modality_aa
dt.loc[:,'Modality_EA'] = modality_ea
dt.to_csv('degs_with_modality.txt', sep='\t')
dt.head()
# Out:
# /home/jbenja13/.local/lib/python3.8/site-packages/pandas/core/indexing.py:1596: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/jbenja13/.local/lib/python3.8/site-packages/pandas/core/indexing.py:1745: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)
#                     Length           gencodeID        ensemblID  \
# ENSG00000154237.12   17600  ENSG00000154237.12  ENSG00000154237
# ENSG00000230076.1      318   ENSG00000230076.1  ENSG00000230076
# ENSG00000233913.7      645   ENSG00000233913.7  ENSG00000233913
# ENSG00000226278.1      261   ENSG00000226278.1  ENSG00000226278
# ENSG00000259583.2     6792   ENSG00000259583.2  ENSG00000259583
#
#                                  gene_type  Symbol     EntrezID  Class  \
# ENSG00000154237.12          protein_coding   LRRK1      79705.0  InGen
# ENSG00000230076.1     processed_pseudogene     NaN          NaN  InGen
# ENSG00000233913.7     processed_pseudogene     NaN          NaN  InGen
# ENSG00000226278.1   unprocessed_pseudogene  PSPHP1          NaN  InGen
# ENSG00000259583.2                antisense     NaN  101927751.0  InGen
#
#                     meanExprs  NumTx  \
# ENSG00000154237.12   0.276253     11
# ENSG00000230076.1    0.598932      1
# ENSG00000233913.7    1.672625      1
# ENSG00000226278.1    1.446923      1
# ENSG00000259583.2    0.322824      3
#
#                                                             gencodeTx  \
# ENSG00000154237.12  ENST00000388948.7|ENST00000534045.5|ENST000005...
# ENSG00000230076.1                                   ENST00000457497.1
# ENSG00000233913.7                                   ENST00000522551.1
# ENSG00000226278.1                                   ENST00000450062.1
# ENSG00000259583.2   ENST00000560351.2|ENST00000560068.1|ENST000005...
#
#                        logFC   AveExpr          t       P.Value     adj.P.Val  \
# ENSG00000154237.12 -1.116997  4.135360 -13.621754  4.660148e-28  9.920990e-24
# ENSG00000230076.1  -3.861304 -2.091205 -12.567775  3.081205e-25  3.279788e-21
# ENSG00000233913.7  -2.272833  1.484546 -11.622463  1.060691e-22  7.527018e-19
# ENSG00000226278.1  -4.320438 -1.326564 -11.566503  1.498506e-22  7.975422e-19
# ENSG00000259583.2  -1.017516  2.929559 -11.006935  4.718776e-21  2.009161e-17
#
#                             B  Modality_AA  Modality_EA
# ENSG00000154237.12  53.114710            1            1
# ENSG00000230076.1   41.413110            2            1
# ENSG00000233913.7   40.276517            2            2
# ENSG00000226278.1   36.911388            2            2
# ENSG00000259583.2   37.168231            1            1
